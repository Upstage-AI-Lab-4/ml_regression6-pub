# %%
# visualization
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumBarunGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumBarunGothic'}) # 폰트 설정
plt.rc('font', family='NanumBarunGothic')
import seaborn as sns

# utils
import pandas as pd
import numpy as np
from tqdm import tqdm
import pickle
import warnings;warnings.filterwarnings('ignore')

# Model
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

import eli5
from eli5.sklearn import PermutationImportance
# Out:
# 2024-09-12 17:02:52.713115: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-12 17:02:52.715624: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-12 17:02:52.724787: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-12 17:02:52.739997: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-12 17:02:52.744592: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-12 17:02:52.755220: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-12 17:02:53.471943: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os
os.getcwd()
concat = pd.read_csv('../data/base_dataset_7.csv')
concat.shape
# Out:
# (1128094, 27)

# %%
str_columns = ['본번', '부번', '거래취소여부', '구', '동', '강남여부', '신축여부']

concat[str_columns] = concat[str_columns].astype(str)

# 먼저, 연속형 변수와 범주형 변수를 위 info에 따라 분리해주겠습니다.
continuous_columns = []
categorical_columns = []

for column in concat.columns:
    if pd.api.types.is_numeric_dtype(concat[column]):
        continuous_columns.append(column)
    else:
        categorical_columns.append(column)

print("연속형 변수:", continuous_columns)
print("범주형 변수:", categorical_columns)
# Out:
# 연속형 변수: ['전용면적', '계약일', '층', '건축년도', 'target', 'is_test', 'x', 'y', '계약년', '계약월', '거래일건물연식', '건축면적', '연면적', '대지면적', '건폐율', '용적율', '평균층수']
# 범주형 변수: ['번지', '본번', '부번', '아파트명', '주소', '거래취소여부', '구', '동', '강남여부', '신축여부']

# %%
# 범주형 변수에 대한 보간
concat[categorical_columns] = concat[categorical_columns].fillna('NULL')

# 연속형 변수에 대한 보간 (선형 보간)
concat[continuous_columns] = concat[continuous_columns].interpolate(method='linear', axis=0)

print(concat.isnull().sum())         # 결측치가 보간된 모습을 확인해봅니다.
print(concat.shape)
# Out:
# 번지         0
# 본번         0
# 부번         0
# 아파트명       0
# 전용면적       0
# 계약일        0
# 층          0
# 건축년도       0
# target     0
# is_test    0
# 주소         0
# x          0
# y          0
# 계약년        0
# 계약월        0
# 거래취소여부     0
# 거래일건물연식    0
# 구          0
# 동          0
# 강남여부       0
# 신축여부       0
# 건축면적       0
# 연면적        0
# 대지면적       0
# 건폐율        0
# 용적율        0
# 평균층수       0
# dtype: int64
# (1128094, 27)

# %%
# test와 train 분리
df = concat.query('is_test == 0')  
df_test = concat.query('is_test == 1')  

# 전용면적 375 이상인 것들은 제거
df= df[df['전용면적'] < 375]

# 층 음수 처리
df['층'] = df['층'].apply(lambda x: 1 if x < 0 else x)
df_test['층'] = df_test['층'].apply(lambda x: 1 if x < 0 else x)

# 건축년도 1965년도 이후에 지어진것만 처리
df= df[df['건축년도'] > 1965]

# 거래일 건물 연식 음수 처리
df= df[df['거래일건물연식'] > 0]
concat_select = pd.concat([df, df_test])
concat_select.info()       # 최종 데이터셋은 아래와 같습니다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108303 entries, 0 to 1128093
# Data columns (total 27 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   번지       1108303 non-null  object
#  1   본번       1108303 non-null  object
#  2   부번       1108303 non-null  object
#  3   아파트명     1108303 non-null  object
#  4   전용면적     1108303 non-null  float64
#  5   계약일      1108303 non-null  int64
#  6   층        1108303 non-null  int64
#  7   건축년도     1108303 non-null  int64
#  8   target   1108303 non-null  float64
#  9   is_test  1108303 non-null  int64
#  10  주소       1108303 non-null  object
#  11  x        1108303 non-null  float64
#  12  y        1108303 non-null  float64
#  13  계약년      1108303 non-null  int64
#  14  계약월      1108303 non-null  int64
#  15  거래취소여부   1108303 non-null  object
#  16  거래일건물연식  1108303 non-null  int64
#  17  구        1108303 non-null  object
#  18  동        1108303 non-null  object
#  19  강남여부     1108303 non-null  object
#  20  신축여부     1108303 non-null  object
#  21  건축면적     1108303 non-null  float64
#  22  연면적      1108303 non-null  float64
#  23  대지면적     1108303 non-null  float64
#  24  건폐율      1108303 non-null  float64
#  25  용적율      1108303 non-null  float64
#  26  평균층수     1108303 non-null  float64
# dtypes: float64(10), int64(7), object(10)
# memory usage: 236.8+ MB

# %%
from math import radians, sin, cos, sqrt, atan2

# 하버사인 공식으로 두 지리적 좌표 간의 거리를 계산하는 함수
def haversine_np(lon1, lat1, lon2, lat2):
    R = 6371  # 지구 반경 (킬로미터)
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c
    return distance
subway_path = pd.read_csv('../data/subway_feature.csv')
bus_path = pd.read_csv('../data/bus_feature.csv')
# concat_select 좌표와 subway_path 좌표를 numpy 배열로 변환
concat_coords = np.array([concat_select['x'], concat_select['y']]).T
subway_coords = np.array([subway_path['경도'], subway_path['위도']]).T
bus_coords = np.array([bus_path['X좌표'], bus_path['Y좌표']]).T
# 빈 리스트를 만들어서 최단 거리를 저장할 것임
shortest_distances_subway = []
shortest_distances_bus = []
# 벡터 연산을 사용하여 가장 가까운 지하철 거리 찾기
for i, concat_coord in tqdm(enumerate(concat_coords), total=len(concat_coords)):
    distances = haversine_np(concat_coord[0], concat_coord[1], subway_coords[:, 0], subway_coords[:, 1])
    min_distance = np.min(distances)
    shortest_distances_subway.append(min_distance)
# 벡터 연산을 사용하여 가장 가까운 버스 거리 찾기
for i, concat_coord in tqdm(enumerate(concat_coords), total=len(concat_coords)):
    distances = haversine_np(concat_coord[0], concat_coord[1], bus_coords[:, 0], bus_coords[:, 1])
    min_distance = np.min(distances)
    shortest_distances_bus.append(min_distance)
# concat_select에 최단 거리를 추가
concat_select['지하철최단거리'] = shortest_distances_subway
concat_select['버스최단거리'] = shortest_distances_bus
concat_select['버스최단거리'].describe()

#거리별 가중치 부여
concat_select['지하철최단거리'] = concat_select['지하철최단거리'].apply(lambda x: 3 if 0 < x < 0.3 else (2 if 0.3 < x < 0.65 else(1 if 0.65<x<1.0 else 0) ))
concat_select['버스최단거리'] = concat_select['버스최단거리'].apply(lambda x: 2 if 0 < x < 0.5 else (1 if 0.5 < x < 1 else 0))


#10분 이내로
# Out:
#   0%|          | 0/1108303 [00:00<?, ?it/s]
# 100%|██████████| 1108303/1108303 [01:14<00:00, 14845.66it/s]
# 100%|██████████| 1108303/1108303 [11:07<00:00, 1659.76it/s]

# %%
brand_patterns = {
   #1군 하이엔트
   '디에이치':3, '푸르지오써밋': 3, '르엘':3,'오티에르':3, '아크로':3,
   #1군
   '힐스테이트': 2, '푸르지오':2, '롯데캐슬':2, '더샵':2, 'e-편한세상':2,'래미안':2 , '아이파크':2, '자이':2,
   #2군 하이엔드
   '위브더제니스':2,'호반써밋':2,
    #2군
    '위브': 1,'우미린':1,'한화포레나':1, '서희스타힐스':1,'더플래티넘':1, '한라비발디':1,'호반베르디움':1, '데시앙':1, '센트레빌':1,'SKVIEW':1,''
    '하늘채': 1,'스위첸':1
}
# 특정 문자열을 포함하는 경우에 따라 값을 반환하는 함수 정의
def assign_brand_value(apartment_name):
    for pattern, value in brand_patterns.items():
        if pattern in apartment_name:
            return value
    return 0
# '아파트브랜드이름'이라는 새로운 열 생성
concat_select['아파트브랜드이름'] = concat_select['아파트명'].apply(assign_brand_value)
print(concat_select.shape, concat_select.columns)
# Out:
# (1108303, 30) Index(['번지', '본번', '부번', '아파트명', '전용면적', '계약일', '층', '건축년도', 'target',
#        'is_test', '주소', 'x', 'y', '계약년', '계약월', '거래취소여부', '거래일건물연식', '구', '동',
#        '강남여부', '신축여부', '건축면적', '연면적', '대지면적', '건폐율', '용적율', '평균층수', '지하철최단거리',
#        '버스최단거리', '아파트브랜드이름'],
#       dtype='object')

# %%
# # 금리 데이터 로드 및 처리
# interest = pd.read_csv('/Users/minseok/Downloads/xgboost/data/한국기준금리07-23.csv')

# interest['계약년월'] = interest['날짜'].astype(str).str[:6]

# interest_grouped = interest.groupby('계약년월').agg({'기준금리': 'mean'}).reset_index()

# concat_select['계약년월'] = concat_select['계약년'].astype(str) + concat_select['계약월'].astype(str)

# concat_select = pd.merge(concat_select, interest_grouped, on='계약년월', how='left')



# print(concat_select.shape, concat_select.columns)

# %%
# concat_select = concat_select.drop(columns=['계약년월'])
# print(concat_select.shape, concat_select.columns)

# %%
import os
os.getcwd()
# Out:
# '/data/ephemeral/home/code'

# %%
school_path = pd.read_csv('./data/청주대학교_지방교육재정연구원_초중등학교위치_20240322.csv', encoding='EUC-KR')
h_school = school_path[school_path['학교급구분'] == '고등학교']
m_school = school_path[school_path['학교급구분'] == '중학교']
p_school = school_path[school_path['학교급구분'] == '초등학교']
h_school_coords = np.array([h_school['경도'], h_school['위도']]).T
m_school_coords = np.array([m_school['경도'], m_school['위도']]).T
p_school_coords = np.array([p_school['경도'], p_school['위도']]).T
# 빈 리스트를 만들어서 최단 거리를 저장할 것임
shortest_distances_h_school = []
shortest_distances_m_school = []
shortest_distances_p_school = []
for i, concat_coord in tqdm(enumerate(concat_coords), total=len(concat_coords)):
    distances = haversine_np(concat_coord[0], concat_coord[1], h_school_coords[:, 0], h_school_coords[:, 1])
    min_distance1 = np.min(distances)
    shortest_distances_h_school.append(min_distance1)
for i, concat_coord in tqdm(enumerate(concat_coords), total=len(concat_coords)):
    distances = haversine_np(concat_coord[0], concat_coord[1], m_school_coords[:, 0], m_school_coords[:, 1])
    min_distance2 = np.min(distances)
    shortest_distances_m_school.append(min_distance2)
for i, concat_coord in tqdm(enumerate(concat_coords), total=len(concat_coords)):
    distances = haversine_np(concat_coord[0], concat_coord[1], p_school_coords[:, 0], p_school_coords[:, 1])
    min_distance3 = np.min(distances)
    shortest_distances_p_school.append(min_distance3)
concat_select['고등학교최단거리'] = shortest_distances_h_school
concat_select['중등학교최단거리'] = shortest_distances_m_school
concat_select['초등학교최단거리'] = shortest_distances_p_school
concat_select['초등학교최단거리'] = concat_select['초등학교최단거리'].apply(lambda x: 3 if 0 < x < 0.5 else (2 if 0.5 < x < 1.0 else(1 if 1.0<x<1.5 else 0) ))
concat_select['중등학교최단거리'] = concat_select['중등학교최단거리'].apply(lambda x: 3 if 0 < x < 0.5 else (2 if 0.5 < x < 1.0 else(1 if 1.0<x<1.5 else 0) ))
concat_select['고등학교최단거리'] = concat_select['고등학교최단거리'].apply(lambda x: 3 if 0 < x < 0.5 else (2 if 0.5 < x < 1.0 else(1 if 1.0<x<1.5 else 0) ))
concat_select.head()
# Out:
# 100%|██████████| 1108303/1108303 [02:36<00:00, 7099.84it/s]
# 100%|██████████| 1108303/1108303 [03:21<00:00, 5487.58it/s]
# 100%|██████████| 1108303/1108303 [05:53<00:00, 3137.84it/s]
#       번지   본번 부번    아파트명   전용면적  계약일  층  건축년도    target  is_test  ...  \
# 0  658-1  658  1  개포6차우성  79.97    8  3  1987  124000.0        0  ...
# 1  658-1  658  1  개포6차우성  79.97   22  4  1987  123500.0        0  ...
# 2  658-1  658  1  개포6차우성  54.98   28  5  1987   91500.0        0  ...
# 3  658-1  658  1  개포6차우성  79.97    3  4  1987  130000.0        0  ...
# 4  658-1  658  1  개포6차우성  79.97    8  2  1987  117000.0        0  ...
#
#             대지면적         건폐율         용적율     평균층수  지하철최단거리 버스최단거리  아파트브랜드이름  \
# 0  171357.334166  297.555783  3143.83423  4.90097        0      2         0
# 1  171357.334166  297.555783  3143.83423  4.90097        0      2         0
# 2  171357.334166  297.555783  3143.83423  4.90097        0      2         0
# 3  171357.334166  297.555783  3143.83423  4.90097        0      2         0
# 4  171357.334166  297.555783  3143.83423  4.90097        0      2         0
#
#   고등학교최단거리 중등학교최단거리 초등학교최단거리
# 0        3        1        3
# 1        3        1        3
# 2        3        1        3
# 3        3        1        3
# 4        3        1        3
#
# [5 rows x 33 columns]

# %%
# str_columns = ['초등학교최단거리', '중등학교최단거리', '고등학교최단거리']

# concat_select[str_columns] = concat_select[str_columns].astype(str)

# print(concat_select.shape)

# %%
# 이제 다시 train과 test dataset을 분할해줍니다. 위에서 제작해 놓았던 is_test 칼럼을 이용합니다.
dt_train = concat_select.query('is_test==0')
dt_test = concat_select.query('is_test==1')

# 결과 출력
print(dt_train.shape, dt_test.shape)

# 이제 is_test 칼럼은 drop해줍니다.
dt_train.drop(['is_test'], axis = 1, inplace=True)
dt_test.drop(['is_test'], axis = 1, inplace=True)
print(dt_train.shape, dt_test.shape)

# dt_test의 target은 일단 0으로 임의로 채워주도록 하겠습니다.
dt_test['target'] = 0
# Out:
# (1099031, 33) (9272, 33)
# (1099031, 32) (9272, 32)

# %%
# 파생변수 제작으로 추가된 변수들이 존재하기에, 다시한번 연속형과 범주형 칼럼을 분리해주겠습니다.
continuous_columns_v2 = []
categorical_columns_v2 = []

for column in dt_train.columns:
    if pd.api.types.is_numeric_dtype(dt_train[column]):
        continuous_columns_v2.append(column)
    else:
        categorical_columns_v2.append(column)

print("연속형 변수:", continuous_columns_v2)
print("범주형 변수:", categorical_columns_v2)

# 아래에서 범주형 변수들을 대상으로 레이블인코딩을 진행해 주겠습니다.

# 각 변수에 대한 LabelEncoder를 저장할 딕셔너리
label_encoders = {}

# Implement Label Encoding
for col in tqdm( categorical_columns_v2 ):
    lbl = LabelEncoder()

    # Label-Encoding을 fit
    lbl.fit( dt_train[col].astype(str) )
    dt_train[col] = lbl.transform(dt_train[col].astype(str))
    label_encoders[col] = lbl           # 나중에 후처리를 위해 레이블인코더를 저장해주겠습니다.

    # Test 데이터에만 존재하는 새로 출현한 데이터를 신규 클래스로 추가해줍니다.
    for label in np.unique(dt_test[col]):
      if label not in lbl.classes_: # unseen label 데이터인 경우
        lbl.classes_ = np.append(lbl.classes_, label) # 미처리 시 ValueError발생하니 주의하세요!

    dt_test[col] = lbl.transform(dt_test[col].astype(str))
# Out:
# 연속형 변수: ['전용면적', '계약일', '층', '건축년도', 'target', 'x', 'y', '계약년', '계약월', '거래일건물연식', '건축면적', '연면적', '대지면적', '건폐율', '용적율', '평균층수', '지하철최단거리', '버스최단거리', '아파트브랜드이름', '고등학교최단거리', '중등학교최단거리', '초등학교최단거리']
# 범주형 변수: ['번지', '본번', '부번', '아파트명', '주소', '거래취소여부', '구', '동', '강남여부', '신축여부']
# 100%|██████████| 10/10 [00:02<00:00,  3.38it/s]

# %%
dt_train = pd.get_dummies(dt_train, columns=['구'])
dt_test = pd.get_dummies(dt_test, columns=['구'])

# %%
columns_to_delete = ['번지', '부번', '본번']

# # 열 삭제
dt_train = dt_train.drop(columns=columns_to_delete)
dt_test = dt_test.drop(columns=columns_to_delete)

# %%
assert dt_train.shape[1] == dt_test.shape[1]          # train/test dataset의 shape이 같은지 확인해주겠습니다.

# Target과 독립변수들을 분리해줍니다.
y_train = dt_train['target']
X_train = dt_train.drop(['target'], axis=1)

# Hold out split을 사용해 학습 데이터와 검증 데이터를 8:2 비율로 나누겠습니다.
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=2023)

# %%
# #  XGBoost 사용

# import xgboost as xgb

# model = xgb.XGBRegressor(objective='reg:squarederror', 
#                          n_estimators=2000,  
#                          learning_rate=0.1,  
#                          max_depth=10,
#                          random_state=1)

# model.fit(X_train, y_train)

# pred_2 = model.predict(X_val)

# # 회귀 관련 metric을 통해 train/valid의 모델 적합 결과를 관찰합니다.
# print(f'RMSE test: {np.sqrt(metrics.mean_squared_error(y_val, pred_2))}')
# Out:
# RMSE test: 5571.655077581897

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid
import joblib
import os

# RMSE 계산 함수
def RMSE(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# 하이퍼파라미터 그리드 설정
param_grid = {
    'n_estimators': [9000, 10000, 11000, 12000],  # 더 높은 n_estimators 설정
    'learning_rate': [0.05, 0.1, 0.15],  # 학습률을 더 세밀하게 설정
    'max_depth': [8, 9, 10],  # max_depth 범위를 확장하여 조정
    'min_child_weight': [1, 3],  # 현재 최적값 유지
    'subsample': [0.8],  # 그대로 유지
    'colsample_bytree': [0.8],  # 그대로 유지
    'gamma': [0],  # 그대로 유지
    'lambda': [1],  # 그대로 유지
    'alpha': [0]  # 그대로 유지
}

# 체크포인트 경로 설정
checkpoint_path = "grid_search_checkpoint.pkl"

# 체크포인트에서 학습 재개
if os.path.exists(checkpoint_path):
    start_idx, best_params, best_rmse = joblib.load(checkpoint_path)
    print(f"Checkpoint 로드 완료, {start_idx}번째 파라미터부터 재개.")
else:
    start_idx = 0
    best_params = None
    best_rmse = float('inf')
    print("새로운 학습 시작.")

# XGBRegressor 모델 정의
xgb_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    random_state=2024
)

# 파라미터 그리드 순회
for idx, params in enumerate(ParameterGrid(param_grid)):
    if idx < start_idx:
        continue  # 이전에 완료된 파라미터 조합은 건너뜀
    
    # 모델 학습
    print(f"{idx + 1}번째 파라미터 조합 학습 중: {params}")
    xgb_model.set_params(**params)
    xgb_model.fit(X_train, y_train)

    # 검증 세트에서 예측
    pred_val = xgb_model.predict(X_val)
    val_rmse = RMSE(y_val, pred_val)
    print(f"Validation RMSE: {val_rmse:.4f}")

    # 최적 파라미터 갱신
    if val_rmse < best_rmse:
        best_rmse = val_rmse
        best_params = params

    # 진행 상황을 체크포인트에 저장
    joblib.dump((idx + 1, best_params, best_rmse), checkpoint_path)
    print(f"Checkpoint 저장됨: {checkpoint_path}")

# 최적 파라미터 및 성능 출력
print(f"최적 파라미터: {best_params}, Best RMSE: {best_rmse:.4f}")

# 최적 모델로 학습 후 모델 저장
best_xgb_model = xgb.XGBRegressor(**best_params, objective='reg:squarederror', random_state=2024)
best_xgb_model.fit(X_train, y_train)
best_xgb_model.save_model(f"xgb_best_model_rmse_{best_rmse:.4f}.model")

# 체크포인트 삭제
if os.path.exists(checkpoint_path):
    os.remove(checkpoint_path)
    print("Checkpoint 파일 삭제 완료.")
# Out:
# 새로운 학습 시작.
# 1번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5444.0422
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 2번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5444.7013
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 3번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5444.6754
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 4번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5445.3693
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 5번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5436.4949
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 6번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5436.8556
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 7번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5439.1674
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 8번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5440.1061
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 9번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5424.6228
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 10번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5426.9931
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 11번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5429.0954
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 12번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5433.9476
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 13번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5448.4151
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 14번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5455.0444
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 15번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5459.6535
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 16번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5463.9437
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 17번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5478.6056
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 18번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5479.5716
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 19번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5482.2562
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 20번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5486.9705
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 21번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5501.2053
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 22번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5505.7428
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 23번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5510.9000
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 24번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5516.7312
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 25번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5505.2050
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 26번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5503.5403
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 27번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5501.7808
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 28번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5508.6691
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 29번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5583.4874
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 30번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5588.1565
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 31번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5591.8567
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 32번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5594.8132
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 33번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5573.0162
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 34번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5577.2653
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 35번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5580.7359
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 36번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5589.6418
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 37번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5584.4780
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 38번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5587.2693
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 39번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5594.7622
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 40번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5598.4141
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 41번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5687.4551
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 42번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5696.7744
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 43번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5700.3942
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 44번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5708.1719
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 45번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5626.2265
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 46번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5631.7073
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 47번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5637.6752
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 48번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5641.7322
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 49번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5654.7864
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 50번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5651.0886
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 51번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5658.4840
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 52번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5664.3796
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 53번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5648.6840
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 54번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5659.9522
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 55번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5666.4758
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 56번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5674.2905
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 57번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5738.0501
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 58번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5748.4955
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 59번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5764.6879
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 60번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5775.3537
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 61번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5772.4630
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 62번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5776.2862
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 63번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5785.1633
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 64번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5788.5093
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 65번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5754.9234
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 66번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5771.7965
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 67번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5771.4090
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 68번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5766.8639
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 69번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 9000, 'subsample': 0.8}
# Validation RMSE: 5773.4413
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 70번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 10000, 'subsample': 0.8}
# Validation RMSE: 5778.2943
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 71번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 11000, 'subsample': 0.8}
# Validation RMSE: 5781.9088
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 72번째 파라미터 조합 학습 중: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.15, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 12000, 'subsample': 0.8}
# Validation RMSE: 5783.1716
# Checkpoint 저장됨: grid_search_checkpoint.pkl
# 최적 파라미터: {'alpha': 0, 'colsample_bytree': 0.8, 'gamma': 0, 'lambda': 1, 'learning_rate': 0.05, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 9000, 'subsample': 0.8}, Best RMSE: 5424.6228
# Checkpoint 파일 삭제 완료.

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
import os
import sys

# RMSE 계산 함수
def RMSE(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# 파일에 로그 저장
log_filename = "training_validation_results_randomsearch.txt"

# 파일에 결과를 기록하는 함수
def log_results(filename, message):
    with open(filename, 'a') as f:
        f.write(f"{message}\n")
        f.write("="*50 + "\n")  # 구분선 추가

# 학습 로그를 파일에 기록하는 함수
class FileLogger:
    def __init__(self, file_name):
        self.file_name = file_name
    
    def __enter__(self):
        self.log_file = open(self.file_name, 'a')
        self.original_stdout = sys.stdout
        sys.stdout = self.log_file  # 출력을 파일로 리다이렉트
        return self.log_file
    
    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout = self.original_stdout  # 원래 stdout으로 복구
        self.log_file.close()

# XGBRegressor 모델 정의
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=2024)

# 하이퍼파라미터 범위 설정
param_distributions = {
    'n_estimators': np.arange(2000, 10000, 500),  # 트리 개수의 더 넓은 범위
    'learning_rate': np.linspace(0.01, 0.02, 10),  # 다양한 학습률
    'max_depth': np.arange(3, 10, 1),  # 깊이 범위 확장
    'min_child_weight': np.arange(1, 10, 1),  # 리프 노드 최소 가중치
    'subsample': np.linspace(0.5, 0.9, 5),  # 샘플링 비율
    'colsample_bytree': np.linspace(0.7, 0.9, 3),  # 피처 샘플링 비율
    'gamma': np.linspace(0, 2, 5),  # 손실 감소를 위한 노드 분할 기준
    'lambda': np.linspace(1, 10, 5),  # L2 정규화 가중치
    'alpha': np.linspace(0, 5, 5)  # L1 정규화 가중치
}

# RandomizedSearchCV 수정
random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_distributions,
    n_iter=50,  # 50번의 무작위 탐색
    scoring='neg_root_mean_squared_error',  # RMSE 최적화
    cv=5,  # 5-fold 교차 검증
    verbose=3,  # 상세한 로그 출력
    n_jobs=-1,
    random_state=2024
)

# 학습 로그를 파일로 기록
with FileLogger(log_filename):
    print("RandomizedSearchCV 시작")

    # RandomizedSearch 실행
    random_search.fit(X_train, y_train)

    # 각 iteration 및 fold 결과를 로그 파일에 저장
    results = random_search.cv_results_

    for i in range(len(results['params'])):
        log_results(log_filename, f"Iteration {i + 1} 결과:")
        log_results(log_filename, f"Parameters: {results['params'][i]}")
        for fold in range(random_search.cv):
            log_results(log_filename, f"Fold {fold + 1} Score: {results['split{}_test_score'.format(fold)][i]:.4f}")

# 최적 하이퍼파라미터 출력 및 저장
best_params = random_search.best_params_
best_rmse = -random_search.best_score_

# 로그 파일에 저장
log_results(log_filename, f"Best Parameters: {best_params}")
log_results(log_filename, f"Best RMSE: {best_rmse:.4f}")

# 최적 하이퍼파라미터로 XGBoost 모델 학습 전에 로그 파일에 기록
log_results(log_filename, f"Training XGBoost with best parameters: {best_params}")

# 최적 하이퍼파라미터로 XGBoost 모델 학습
best_xgb_model = xgb.XGBRegressor(
    **best_params, 
    objective='reg:squarederror',
    random_state=2024
)

# 학습 로그를 파일로 기록
with FileLogger(log_filename):
    print(f"XGBoost 학습 시작 - n_estimators: {best_params['n_estimators']}")
    
    # 최적 모델로 학습
    best_xgb_model.fit(X_train, y_train)

# 검증 세트에서 예측
pred_val = best_xgb_model.predict(X_val)
pred_train = best_xgb_model.predict(X_train)

# RMSE 계산 (학습 데이터와 검증 데이터)
train_rmse = RMSE(y_train, pred_train)
val_rmse = RMSE(y_val, pred_val)

# 파라미터 및 성능을 반영한 파일명 생성
model_filename = (f"xgb_n{best_params['n_estimators']}_lr{best_params['learning_rate']}_md{best_params['max_depth']}_"
                  f"mcw{best_params['min_child_weight']}_sub{best_params['subsample']}_csbt{best_params['colsample_bytree']}_"
                  f"g{best_params['gamma']}_lambda{best_params['lambda']}_alpha{best_params['alpha']}_"
                  f"train_rmse{train_rmse:.4f}_val_rmse{val_rmse:.4f}.model")

# 모델 저장
best_xgb_model.save_model(model_filename)

# 결과 로그 파일에 저장
result_info = (
    f"Model Training End\n"
    f"Model: {model_filename}\n"
    f"Train RMSE: {train_rmse:.4f}, Validation RMSE: {val_rmse:.4f}"
)
log_results(log_filename, result_info)

print(f"모델 저장됨: {model_filename}, Train RMSE: {train_rmse:.4f}, Validation RMSE: {val_rmse:.4f}")
# Out:
# [CV 5/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.6;, score=-11888.582 total time= 3.1min
# [CV 2/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.6;, score=-11586.441 total time= 3.1min
# [CV 1/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.6;, score=-11491.662 total time= 3.1min
# [CV 4/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.6;, score=-11504.761 total time= 3.1min
# [CV 3/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.6;, score=-11709.383 total time= 3.2min
# [CV 2/5] END alpha=5.0, colsample_bytree=0.9, gamma=2.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=6, n_estimators=5000, subsample=0.7;, score=-5922.078 total time=10.0min
# [CV 1/5] END alpha=5.0, colsample_bytree=0.9, gamma=2.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=6, n_estimators=5000, subsample=0.7;, score=-6073.910 total time=10.0min
# [CV 3/5] END alpha=5.0, colsample_bytree=0.9, gamma=2.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=6, n_estimators=5000, subsample=0.7;, score=-5932.129 total time=10.0min
# [CV 5/5] END alpha=5.0, colsample_bytree=0.9, gamma=2.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=6, n_estimators=5000, subsample=0.7;, score=-6198.719 total time=10.0min
# [CV 4/5] END alpha=5.0, colsample_bytree=0.9, gamma=2.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=6, n_estimators=5000, subsample=0.7;, score=-5756.408 total time=10.0min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.02, max_depth=9, min_child_weight=8, n_estimators=9000, subsample=0.7;, score=-5800.493 total time=17.3min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.02, max_depth=9, min_child_weight=8, n_estimators=9000, subsample=0.7;, score=-6076.987 total time=17.4min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.02, max_depth=9, min_child_weight=8, n_estimators=9000, subsample=0.7;, score=-5851.854 total time=17.5min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.02, max_depth=9, min_child_weight=8, n_estimators=9000, subsample=0.7;, score=-5949.568 total time=17.5min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.02, max_depth=9, min_child_weight=8, n_estimators=9000, subsample=0.7;, score=-5596.519 total time=17.5min
# [CV 2/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=4, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-8190.376 total time= 8.3min
# [CV 1/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=4, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-8109.593 total time= 8.5min
# [CV 3/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=4, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-8270.347 total time= 8.4min
# [CV 4/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=4, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-8046.895 total time= 8.4min
# [CV 5/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=4, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-8346.898 total time= 8.5min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=1.0, learning_rate=0.015555555555555555, max_depth=7, min_child_weight=1, n_estimators=9500, subsample=0.5;, score=-6136.281 total time=14.3min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=1.0, learning_rate=0.015555555555555555, max_depth=7, min_child_weight=1, n_estimators=9500, subsample=0.5;, score=-6048.351 total time=14.3min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=1.0, learning_rate=0.015555555555555555, max_depth=7, min_child_weight=1, n_estimators=9500, subsample=0.5;, score=-5996.966 total time=14.3min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=1.0, learning_rate=0.015555555555555555, max_depth=7, min_child_weight=1, n_estimators=9500, subsample=0.5;, score=-6279.612 total time=14.4min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=1.0, learning_rate=0.015555555555555555, max_depth=7, min_child_weight=1, n_estimators=9500, subsample=0.5;, score=-5803.250 total time=14.8min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.014444444444444444, max_depth=5, min_child_weight=1, n_estimators=4000, subsample=0.8;, score=-7888.716 total time= 4.6min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.014444444444444444, max_depth=5, min_child_weight=1, n_estimators=4000, subsample=0.8;, score=-7975.225 total time= 4.5min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.014444444444444444, max_depth=5, min_child_weight=1, n_estimators=4000, subsample=0.8;, score=-8054.374 total time= 4.5min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.014444444444444444, max_depth=5, min_child_weight=1, n_estimators=4000, subsample=0.8;, score=-7844.552 total time= 4.7min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.014444444444444444, max_depth=5, min_child_weight=1, n_estimators=4000, subsample=0.8;, score=-8128.096 total time= 4.6min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=8, n_estimators=6000, subsample=0.6;, score=-6027.937 total time=11.1min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=8, n_estimators=6000, subsample=0.6;, score=-5957.684 total time=11.1min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=8, n_estimators=6000, subsample=0.6;, score=-5753.760 total time=11.1min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=8, n_estimators=6000, subsample=0.6;, score=-5932.277 total time=11.2min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=8, n_estimators=6000, subsample=0.6;, score=-6172.667 total time=11.4min
# [CV 2/5] END alpha=3.75, colsample_bytree=0.7, gamma=2.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=9, n_estimators=6500, subsample=0.7;, score=-5933.444 total time=11.5min
# [CV 1/5] END alpha=3.75, colsample_bytree=0.7, gamma=2.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=9, n_estimators=6500, subsample=0.7;, score=-6045.020 total time=11.7min
# [CV 3/5] END alpha=3.75, colsample_bytree=0.7, gamma=2.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=9, n_estimators=6500, subsample=0.7;, score=-5949.654 total time=11.7min
# [CV 4/5] END alpha=3.75, colsample_bytree=0.7, gamma=2.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=9, n_estimators=6500, subsample=0.7;, score=-5754.495 total time=11.6min
# [CV 5/5] END alpha=3.75, colsample_bytree=0.7, gamma=2.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=9, min_child_weight=9, n_estimators=6500, subsample=0.7;, score=-6187.597 total time=11.8min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=5.5, learning_rate=0.017777777777777778, max_depth=6, min_child_weight=3, n_estimators=5500, subsample=0.5;, score=-6544.425 total time= 6.7min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=5.5, learning_rate=0.017777777777777778, max_depth=6, min_child_weight=3, n_estimators=5500, subsample=0.5;, score=-6710.230 total time= 6.8min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=5.5, learning_rate=0.017777777777777778, max_depth=6, min_child_weight=3, n_estimators=5500, subsample=0.5;, score=-6703.893 total time= 6.7min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=5.5, learning_rate=0.017777777777777778, max_depth=6, min_child_weight=3, n_estimators=5500, subsample=0.5;, score=-6768.870 total time= 6.8min
# [CV 1/5] END alpha=3.75, colsample_bytree=0.8, gamma=0.0, lambda=10.0, learning_rate=0.012222222222222223, max_depth=5, min_child_weight=3, n_estimators=3500, subsample=0.7;, score=-8439.555 total time= 4.0min
# [CV 2/5] END alpha=3.75, colsample_bytree=0.8, gamma=0.0, lambda=10.0, learning_rate=0.012222222222222223, max_depth=5, min_child_weight=3, n_estimators=3500, subsample=0.7;, score=-8526.170 total time= 4.0min
# [CV 4/5] END alpha=3.75, colsample_bytree=0.8, gamma=0.0, lambda=10.0, learning_rate=0.012222222222222223, max_depth=5, min_child_weight=3, n_estimators=3500, subsample=0.7;, score=-8406.275 total time= 3.9min
# [CV 3/5] END alpha=3.75, colsample_bytree=0.8, gamma=0.0, lambda=10.0, learning_rate=0.012222222222222223, max_depth=5, min_child_weight=3, n_estimators=3500, subsample=0.7;, score=-8633.403 total time= 4.0min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=5.5, learning_rate=0.017777777777777778, max_depth=6, min_child_weight=3, n_estimators=5500, subsample=0.5;, score=-6909.359 total time= 6.8min
# [CV 5/5] END alpha=3.75, colsample_bytree=0.8, gamma=0.0, lambda=10.0, learning_rate=0.012222222222222223, max_depth=5, min_child_weight=3, n_estimators=3500, subsample=0.7;, score=-8760.882 total time= 4.0min
# [CV 2/5] END alpha=3.75, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=8000, subsample=0.8;, score=-7840.197 total time= 7.4min
# [CV 1/5] END alpha=3.75, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=8000, subsample=0.8;, score=-7780.224 total time= 7.6min
# [CV 3/5] END alpha=3.75, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=8000, subsample=0.8;, score=-7917.852 total time= 7.5min
# [CV 4/5] END alpha=3.75, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=8000, subsample=0.8;, score=-7678.747 total time= 7.6min
# [CV 5/5] END alpha=3.75, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=8000, subsample=0.8;, score=-7978.364 total time= 7.6min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.0, lambda=7.75, learning_rate=0.01, max_depth=9, min_child_weight=7, n_estimators=8000, subsample=0.7;, score=-6079.059 total time=14.5min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.0, lambda=7.75, learning_rate=0.01, max_depth=9, min_child_weight=7, n_estimators=8000, subsample=0.7;, score=-5774.042 total time=14.5min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.0, lambda=7.75, learning_rate=0.01, max_depth=9, min_child_weight=7, n_estimators=8000, subsample=0.7;, score=-5959.114 total time=14.5min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.0, lambda=7.75, learning_rate=0.01, max_depth=9, min_child_weight=7, n_estimators=8000, subsample=0.7;, score=-5963.447 total time=14.6min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.0, lambda=7.75, learning_rate=0.01, max_depth=9, min_child_weight=7, n_estimators=8000, subsample=0.7;, score=-6210.647 total time=14.6min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.014444444444444444, max_depth=4, min_child_weight=6, n_estimators=9000, subsample=0.9;, score=-7872.545 total time= 8.3min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.014444444444444444, max_depth=4, min_child_weight=6, n_estimators=9000, subsample=0.9;, score=-8049.356 total time= 8.3min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.014444444444444444, max_depth=4, min_child_weight=6, n_estimators=9000, subsample=0.9;, score=-7985.598 total time= 8.4min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.014444444444444444, max_depth=4, min_child_weight=6, n_estimators=9000, subsample=0.9;, score=-7817.174 total time= 8.4min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.014444444444444444, max_depth=4, min_child_weight=6, n_estimators=9000, subsample=0.9;, score=-8115.340 total time= 8.3min
# [CV 1/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.02, max_depth=3, min_child_weight=2, n_estimators=3000, subsample=0.9;, score=-11325.046 total time= 2.5min
# [CV 2/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.02, max_depth=3, min_child_weight=2, n_estimators=3000, subsample=0.9;, score=-11404.737 total time= 2.5min
# [CV 3/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.02, max_depth=3, min_child_weight=2, n_estimators=3000, subsample=0.9;, score=-11517.940 total time= 2.5min
# [CV 4/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.02, max_depth=3, min_child_weight=2, n_estimators=3000, subsample=0.9;, score=-11295.729 total time= 2.5min
# [CV 5/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.02, max_depth=3, min_child_weight=2, n_estimators=3000, subsample=0.9;, score=-11650.697 total time= 2.5min
# [CV 1/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-11446.804 total time= 3.1min
# [CV 2/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-11440.451 total time= 3.1min
# [CV 3/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-11592.098 total time= 3.1min
# [CV 4/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-11390.168 total time= 3.2min
# [CV 5/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.015555555555555555, max_depth=3, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-11769.590 total time= 3.1min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.014444444444444444, max_depth=7, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-6818.158 total time= 4.9min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.014444444444444444, max_depth=7, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-6768.528 total time= 5.0min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.014444444444444444, max_depth=7, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-6662.217 total time= 5.0min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.014444444444444444, max_depth=7, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-6787.929 total time= 5.0min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.014444444444444444, max_depth=7, min_child_weight=5, n_estimators=3500, subsample=0.5;, score=-6944.390 total time= 5.1min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.7;, score=-6142.121 total time= 9.1min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.7;, score=-6045.010 total time= 9.0min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.7;, score=-6050.611 total time= 9.1min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.7;, score=-5876.233 total time= 9.1min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=3.25, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.7;, score=-6314.095 total time= 9.3min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=9500, subsample=0.5;, score=-5844.718 total time=18.8min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=9500, subsample=0.5;, score=-5854.570 total time=19.0min
# [CV 1/5] END alpha=5.0, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=8, n_estimators=5500, subsample=0.9;, score=-6439.917 total time= 7.8min
# [CV 2/5] END alpha=5.0, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=8, n_estimators=5500, subsample=0.9;, score=-6369.157 total time= 7.8min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=9500, subsample=0.5;, score=-5605.024 total time=19.1min
# [CV 4/5] END alpha=5.0, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=8, n_estimators=5500, subsample=0.9;, score=-6237.295 total time= 7.9min
# [CV 3/5] END alpha=5.0, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=8, n_estimators=5500, subsample=0.9;, score=-6343.425 total time= 8.0min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=9500, subsample=0.5;, score=-5934.199 total time=19.6min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.9, gamma=2.0, lambda=3.25, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=9500, subsample=0.5;, score=-6112.907 total time=19.2min
# [CV 5/5] END alpha=5.0, colsample_bytree=0.9, gamma=0.5, lambda=3.25, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=8, n_estimators=5500, subsample=0.9;, score=-6572.681 total time= 7.9min
# [CV 1/5] END alpha=5.0, colsample_bytree=0.8, gamma=0.0, lambda=5.5, learning_rate=0.011111111111111112, max_depth=5, min_child_weight=5, n_estimators=2500, subsample=0.7;, score=-9181.429 total time= 2.9min
# [CV 2/5] END alpha=5.0, colsample_bytree=0.8, gamma=0.0, lambda=5.5, learning_rate=0.011111111111111112, max_depth=5, min_child_weight=5, n_estimators=2500, subsample=0.7;, score=-9286.639 total time= 3.0min
# [CV 4/5] END alpha=5.0, colsample_bytree=0.8, gamma=0.0, lambda=5.5, learning_rate=0.011111111111111112, max_depth=5, min_child_weight=5, n_estimators=2500, subsample=0.7;, score=-9210.968 total time= 3.0min
# [CV 3/5] END alpha=5.0, colsample_bytree=0.8, gamma=0.0, lambda=5.5, learning_rate=0.011111111111111112, max_depth=5, min_child_weight=5, n_estimators=2500, subsample=0.7;, score=-9410.019 total time= 3.3min
# [CV 5/5] END alpha=5.0, colsample_bytree=0.8, gamma=0.0, lambda=5.5, learning_rate=0.011111111111111112, max_depth=5, min_child_weight=5, n_estimators=2500, subsample=0.7;, score=-9564.315 total time= 3.0min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=8500, subsample=0.6;, score=-8604.151 total time= 8.3min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=8500, subsample=0.6;, score=-8675.118 total time= 8.2min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=8500, subsample=0.6;, score=-8563.413 total time= 8.4min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=8500, subsample=0.6;, score=-8885.652 total time= 8.4min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.7, gamma=2.0, lambda=7.75, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=8500, subsample=0.6;, score=-8761.900 total time= 8.8min
# [CV 1/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.5, lambda=5.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=9000, subsample=0.8;, score=-10381.145 total time= 7.6min
# [CV 2/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.5, lambda=5.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=9000, subsample=0.8;, score=-10440.217 total time= 7.6min
# [CV 3/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.5, lambda=5.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=9000, subsample=0.8;, score=-10553.551 total time= 7.7min
# [CV 4/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.5, lambda=5.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=9000, subsample=0.8;, score=-10380.759 total time= 7.6min
# [CV 5/5] END alpha=3.75, colsample_bytree=0.7, gamma=0.5, lambda=5.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=9000, subsample=0.8;, score=-10762.101 total time= 7.6min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=7.75, learning_rate=0.017777777777777778, max_depth=3, min_child_weight=4, n_estimators=9000, subsample=0.9;, score=-9373.094 total time= 7.4min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=7.75, learning_rate=0.017777777777777778, max_depth=3, min_child_weight=4, n_estimators=9000, subsample=0.9;, score=-9224.288 total time= 7.5min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=7.75, learning_rate=0.017777777777777778, max_depth=3, min_child_weight=4, n_estimators=9000, subsample=0.9;, score=-9435.818 total time= 7.4min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=7.75, learning_rate=0.017777777777777778, max_depth=3, min_child_weight=4, n_estimators=9000, subsample=0.9;, score=-9225.321 total time= 7.4min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=7.75, learning_rate=0.017777777777777778, max_depth=3, min_child_weight=4, n_estimators=9000, subsample=0.9;, score=-9605.859 total time= 7.3min
# [CV 1/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=7.75, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=8000, subsample=0.8;, score=-5916.771 total time=15.5min
# [CV 2/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=7.75, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=8000, subsample=0.8;, score=-5847.632 total time=15.4min
# [CV 4/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=7.75, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=8000, subsample=0.8;, score=-5590.215 total time=15.3min
# [CV 3/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=7.75, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=8000, subsample=0.8;, score=-5835.883 total time=15.5min
# [CV 5/5] END alpha=1.25, colsample_bytree=0.8, gamma=1.5, lambda=7.75, learning_rate=0.015555555555555555, max_depth=9, min_child_weight=2, n_estimators=8000, subsample=0.8;, score=-6092.020 total time=15.5min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=2, n_estimators=6500, subsample=0.9;, score=-5957.765 total time=12.5min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=2, n_estimators=6500, subsample=0.9;, score=-5875.368 total time=12.5min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=2, n_estimators=6500, subsample=0.9;, score=-5862.966 total time=12.4min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=2, n_estimators=6500, subsample=0.9;, score=-5656.058 total time=12.5min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=2, n_estimators=6500, subsample=0.9;, score=-6147.295 total time=12.4min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=5, n_estimators=4000, subsample=0.7;, score=-10999.520 total time= 3.4min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=5, n_estimators=4000, subsample=0.7;, score=-10988.216 total time= 3.4min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=5, n_estimators=4000, subsample=0.7;, score=-11212.435 total time= 3.4min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=5, n_estimators=4000, subsample=0.7;, score=-10973.692 total time= 3.5min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=5, n_estimators=4000, subsample=0.7;, score=-11357.194 total time= 3.4min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.014444444444444444, max_depth=6, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-7374.071 total time= 3.8min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.014444444444444444, max_depth=6, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-7366.768 total time= 3.9min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.014444444444444444, max_depth=6, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-7418.614 total time= 3.8min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.014444444444444444, max_depth=6, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-7276.764 total time= 3.8min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.014444444444444444, max_depth=6, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-7534.904 total time= 3.9min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=5500, subsample=0.8;, score=-8355.844 total time= 5.2min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=5500, subsample=0.8;, score=-8446.245 total time= 5.2min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=5500, subsample=0.8;, score=-8526.825 total time= 5.3min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=5500, subsample=0.8;, score=-8323.598 total time= 5.3min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=6, n_estimators=5500, subsample=0.8;, score=-8612.895 total time= 5.4min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.7, gamma=2.0, lambda=3.25, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.9;, score=-6007.282 total time= 8.7min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.7, gamma=2.0, lambda=3.25, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.9;, score=-5940.090 total time= 8.8min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.7, gamma=2.0, lambda=3.25, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.9;, score=-5925.573 total time= 8.7min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.7, gamma=2.0, lambda=3.25, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.9;, score=-5754.939 total time= 8.7min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.7, gamma=2.0, lambda=3.25, learning_rate=0.012222222222222223, max_depth=9, min_child_weight=3, n_estimators=4500, subsample=0.9;, score=-6177.212 total time= 8.7min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=3, n_estimators=8000, subsample=0.6;, score=-9550.211 total time= 6.8min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=3, n_estimators=8000, subsample=0.6;, score=-9487.622 total time= 6.9min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=3, n_estimators=8000, subsample=0.6;, score=-9670.324 total time= 6.9min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=3, n_estimators=8000, subsample=0.6;, score=-9428.483 total time= 6.9min
# [CV 1/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.02, max_depth=4, min_child_weight=8, n_estimators=2000, subsample=0.8;, score=-10056.502 total time= 2.0min
# [CV 2/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.02, max_depth=4, min_child_weight=8, n_estimators=2000, subsample=0.8;, score=-10132.855 total time= 2.0min
# [CV 3/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.02, max_depth=4, min_child_weight=8, n_estimators=2000, subsample=0.8;, score=-10296.629 total time= 2.0min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=1.0, learning_rate=0.016666666666666666, max_depth=3, min_child_weight=3, n_estimators=8000, subsample=0.6;, score=-9801.936 total time= 7.0min
# [CV 4/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.02, max_depth=4, min_child_weight=8, n_estimators=2000, subsample=0.8;, score=-10117.722 total time= 2.0min
# [CV 5/5] END alpha=5.0, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.02, max_depth=4, min_child_weight=8, n_estimators=2000, subsample=0.8;, score=-10469.937 total time= 2.1min
# [CV 1/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.02, max_depth=8, min_child_weight=9, n_estimators=4000, subsample=0.7;, score=-6212.788 total time= 6.4min
# [CV 2/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.02, max_depth=8, min_child_weight=9, n_estimators=4000, subsample=0.7;, score=-6109.023 total time= 6.4min
# [CV 3/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.02, max_depth=8, min_child_weight=9, n_estimators=4000, subsample=0.7;, score=-6104.631 total time= 6.4min
# [CV 4/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.02, max_depth=8, min_child_weight=9, n_estimators=4000, subsample=0.7;, score=-5922.258 total time= 6.5min
# [CV 5/5] END alpha=1.25, colsample_bytree=0.7, gamma=0.0, lambda=5.5, learning_rate=0.02, max_depth=8, min_child_weight=9, n_estimators=4000, subsample=0.7;, score=-6320.934 total time= 6.5min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.9, gamma=1.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=8, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-6132.805 total time=13.6min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.9, gamma=1.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=8, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-5990.502 total time=13.6min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.9, gamma=1.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=8, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-5806.061 total time=13.5min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.9, gamma=1.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=8, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-5981.756 total time=13.7min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.9, gamma=1.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=8, min_child_weight=9, n_estimators=8500, subsample=0.8;, score=-6254.755 total time=13.7min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=10.0, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=9000, subsample=0.8;, score=-7419.544 total time= 9.9min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=10.0, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=9000, subsample=0.8;, score=-7378.143 total time=10.0min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=10.0, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=9000, subsample=0.8;, score=-7483.056 total time=10.1min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=10.0, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=9000, subsample=0.8;, score=-7301.528 total time=10.0min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.9, gamma=2.0, lambda=10.0, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=9000, subsample=0.8;, score=-7585.540 total time=10.0min
# [CV 1/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=9, n_estimators=5500, subsample=0.8;, score=-7692.327 total time= 6.2min
# [CV 2/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=9, n_estimators=5500, subsample=0.8;, score=-7714.566 total time= 6.1min
# [CV 3/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=9, n_estimators=5500, subsample=0.8;, score=-7811.048 total time= 6.2min
# [CV 4/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=9, n_estimators=5500, subsample=0.8;, score=-7619.941 total time= 6.2min
# [CV 5/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=9, n_estimators=5500, subsample=0.8;, score=-7905.599 total time= 6.2min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.02, max_depth=5, min_child_weight=7, n_estimators=6500, subsample=0.6;, score=-7093.009 total time= 7.2min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.02, max_depth=5, min_child_weight=7, n_estimators=6500, subsample=0.6;, score=-7073.594 total time= 7.2min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.02, max_depth=5, min_child_weight=7, n_estimators=6500, subsample=0.6;, score=-6910.898 total time= 7.2min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.02, max_depth=5, min_child_weight=7, n_estimators=6500, subsample=0.6;, score=-7089.904 total time= 7.3min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.8, gamma=1.5, lambda=3.25, learning_rate=0.02, max_depth=5, min_child_weight=7, n_estimators=6500, subsample=0.6;, score=-7190.289 total time= 7.4min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=8, n_estimators=5000, subsample=0.9;, score=-8495.243 total time= 4.9min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=8, n_estimators=5000, subsample=0.9;, score=-8610.163 total time= 4.9min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=8, n_estimators=5000, subsample=0.9;, score=-8730.455 total time= 4.9min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=8, n_estimators=5000, subsample=0.9;, score=-8488.090 total time= 4.9min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.7, gamma=0.0, lambda=3.25, learning_rate=0.017777777777777778, max_depth=4, min_child_weight=8, n_estimators=5000, subsample=0.9;, score=-8821.706 total time= 5.1min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=6, min_child_weight=4, n_estimators=7500, subsample=0.5;, score=-6695.311 total time=10.0min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=6, min_child_weight=4, n_estimators=7500, subsample=0.5;, score=-6657.582 total time= 9.9min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=6, min_child_weight=4, n_estimators=7500, subsample=0.5;, score=-6639.725 total time=10.0min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=6, min_child_weight=4, n_estimators=7500, subsample=0.5;, score=-6492.411 total time= 9.9min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.7, gamma=1.0, lambda=3.25, learning_rate=0.013333333333333332, max_depth=6, min_child_weight=4, n_estimators=7500, subsample=0.5;, score=-6810.501 total time=10.0min
# [CV 2/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=3, n_estimators=9000, subsample=0.9;, score=-6117.025 total time=13.2min
# [CV 1/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=3, n_estimators=9000, subsample=0.9;, score=-6193.922 total time=13.2min
# [CV 4/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=3, n_estimators=9000, subsample=0.9;, score=-5936.909 total time=13.0min
# [CV 3/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=3, n_estimators=9000, subsample=0.9;, score=-6084.698 total time=13.1min
# [CV 5/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=10.0, learning_rate=0.013333333333333332, max_depth=7, min_child_weight=3, n_estimators=9000, subsample=0.9;, score=-6348.590 total time=13.2min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=1.0, learning_rate=0.011111111111111112, max_depth=6, min_child_weight=3, n_estimators=9000, subsample=0.7;, score=-6488.839 total time=11.2min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=1.0, learning_rate=0.011111111111111112, max_depth=6, min_child_weight=3, n_estimators=9000, subsample=0.7;, score=-6578.031 total time=11.3min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=1.0, learning_rate=0.011111111111111112, max_depth=6, min_child_weight=3, n_estimators=9000, subsample=0.7;, score=-6485.585 total time=11.3min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=1.0, learning_rate=0.011111111111111112, max_depth=6, min_child_weight=3, n_estimators=9000, subsample=0.7;, score=-6355.489 total time=11.8min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.8, gamma=0.0, lambda=1.0, learning_rate=0.011111111111111112, max_depth=6, min_child_weight=3, n_estimators=9000, subsample=0.7;, score=-6699.495 total time=11.4min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.01888888888888889, max_depth=9, min_child_weight=5, n_estimators=6500, subsample=0.5;, score=-6000.717 total time=11.7min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.01888888888888889, max_depth=9, min_child_weight=5, n_estimators=6500, subsample=0.5;, score=-5900.176 total time=11.7min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.01888888888888889, max_depth=9, min_child_weight=5, n_estimators=6500, subsample=0.5;, score=-5904.471 total time=11.8min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.01888888888888889, max_depth=9, min_child_weight=5, n_estimators=6500, subsample=0.5;, score=-5673.749 total time=11.9min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.01888888888888889, max_depth=9, min_child_weight=5, n_estimators=6500, subsample=0.5;, score=-6122.018 total time=11.9min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.016666666666666666, max_depth=5, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-8221.158 total time= 3.4min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.016666666666666666, max_depth=5, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-8277.414 total time= 3.4min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.016666666666666666, max_depth=5, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-8349.629 total time= 3.4min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.016666666666666666, max_depth=5, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-8151.851 total time= 3.4min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.7, gamma=1.5, lambda=7.75, learning_rate=0.016666666666666666, max_depth=5, min_child_weight=3, n_estimators=3000, subsample=0.6;, score=-8468.092 total time= 3.4min
# [CV 1/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=8, n_estimators=3000, subsample=0.8;, score=-8556.590 total time= 3.4min
# [CV 2/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=8, n_estimators=3000, subsample=0.8;, score=-8659.223 total time= 3.4min
# [CV 3/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=8, n_estimators=3000, subsample=0.8;, score=-8755.538 total time= 3.5min
# [CV 4/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=8, n_estimators=3000, subsample=0.8;, score=-8553.116 total time= 3.5min
# [CV 5/5] END alpha=2.5, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.013333333333333332, max_depth=5, min_child_weight=8, n_estimators=3000, subsample=0.8;, score=-8877.046 total time= 3.4min
# [CV 1/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=5, min_child_weight=9, n_estimators=2500, subsample=0.7;, score=-8577.226 total time= 2.9min
# [CV 2/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=5, min_child_weight=9, n_estimators=2500, subsample=0.7;, score=-8664.909 total time= 2.9min
# [CV 3/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=5, min_child_weight=9, n_estimators=2500, subsample=0.7;, score=-8757.487 total time= 2.9min
# [CV 4/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=5, min_child_weight=9, n_estimators=2500, subsample=0.7;, score=-8557.083 total time= 2.9min
# [CV 5/5] END alpha=3.75, colsample_bytree=0.9, gamma=0.0, lambda=5.5, learning_rate=0.015555555555555555, max_depth=5, min_child_weight=9, n_estimators=2500, subsample=0.7;, score=-8867.767 total time= 2.9min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=3.25, learning_rate=0.01888888888888889, max_depth=8, min_child_weight=9, n_estimators=9000, subsample=0.6;, score=-5930.438 total time=13.9min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=3.25, learning_rate=0.01888888888888889, max_depth=8, min_child_weight=9, n_estimators=9000, subsample=0.6;, score=-6066.322 total time=13.9min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=3.25, learning_rate=0.01888888888888889, max_depth=8, min_child_weight=9, n_estimators=9000, subsample=0.6;, score=-5915.453 total time=14.1min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=3.25, learning_rate=0.01888888888888889, max_depth=8, min_child_weight=9, n_estimators=9000, subsample=0.6;, score=-5732.456 total time=13.9min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.9, gamma=1.0, lambda=3.25, learning_rate=0.01888888888888889, max_depth=8, min_child_weight=9, n_estimators=9000, subsample=0.6;, score=-6177.439 total time=14.0min
# [CV 1/5] END alpha=1.25, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=3, n_estimators=4000, subsample=0.7;, score=-7303.617 total time= 5.0min
# [CV 2/5] END alpha=1.25, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=3, n_estimators=4000, subsample=0.7;, score=-7316.064 total time= 5.0min
# [CV 3/5] END alpha=1.25, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=3, n_estimators=4000, subsample=0.7;, score=-7394.963 total time= 5.1min
# [CV 4/5] END alpha=1.25, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=3, n_estimators=4000, subsample=0.7;, score=-7218.291 total time= 5.2min
# [CV 5/5] END alpha=1.25, colsample_bytree=0.7, gamma=2.0, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=3, n_estimators=4000, subsample=0.7;, score=-7511.838 total time= 5.0min
# [CV 2/5] END alpha=5.0, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=9, n_estimators=3000, subsample=0.6;, score=-7744.070 total time= 3.9min
# [CV 1/5] END alpha=5.0, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=9, n_estimators=3000, subsample=0.6;, score=-7725.577 total time= 3.9min
# [CV 1/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.01, max_depth=7, min_child_weight=6, n_estimators=4500, subsample=0.7;, score=-6892.121 total time= 6.5min
# [CV 2/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.01, max_depth=7, min_child_weight=6, n_estimators=4500, subsample=0.7;, score=-6863.338 total time= 6.9min
# [CV 3/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.01, max_depth=7, min_child_weight=6, n_estimators=4500, subsample=0.7;, score=-6902.038 total time= 6.6min
# [CV 3/5] END alpha=5.0, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=9, n_estimators=3000, subsample=0.6;, score=-7835.493 total time= 4.0min
# [CV 4/5] END alpha=5.0, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=9, n_estimators=3000, subsample=0.6;, score=-7664.927 total time= 3.9min
# [CV 4/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.01, max_depth=7, min_child_weight=6, n_estimators=4500, subsample=0.7;, score=-6769.954 total time= 6.6min
# [CV 5/5] END alpha=5.0, colsample_bytree=0.7, gamma=1.5, lambda=5.5, learning_rate=0.012222222222222223, max_depth=6, min_child_weight=9, n_estimators=3000, subsample=0.6;, score=-7943.022 total time= 3.9min
# [CV 5/5] END alpha=0.0, colsample_bytree=0.9, gamma=0.5, lambda=10.0, learning_rate=0.01, max_depth=7, min_child_weight=6, n_estimators=4500, subsample=0.7;, score=-7049.276 total time= 6.6min
# [CV 1/5] END alpha=1.25, colsample_bytree=0.8, gamma=0.5, lambda=3.25, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=2000, subsample=0.5;, score=-6950.349 total time= 2.9min
# [CV 2/5] END alpha=1.25, colsample_bytree=0.8, gamma=0.5, lambda=3.25, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=2000, subsample=0.5;, score=-6910.637 total time= 2.9min
# [CV 3/5] END alpha=1.25, colsample_bytree=0.8, gamma=0.5, lambda=3.25, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=2000, subsample=0.5;, score=-6958.993 total time= 2.9min
# [CV 4/5] END alpha=1.25, colsample_bytree=0.8, gamma=0.5, lambda=3.25, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=2000, subsample=0.5;, score=-6793.630 total time= 2.9min
# [CV 5/5] END alpha=1.25, colsample_bytree=0.8, gamma=0.5, lambda=3.25, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=2000, subsample=0.5;, score=-7090.059 total time= 2.9min
# [CV 1/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=7.75, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=2500, subsample=0.6;, score=-7366.235 total time= 3.1min
# [CV 2/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=7.75, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=2500, subsample=0.6;, score=-7380.478 total time= 3.1min
# [CV 3/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=7.75, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=2500, subsample=0.6;, score=-7408.913 total time= 3.1min
# [CV 4/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=7.75, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=2500, subsample=0.6;, score=-7258.040 total time= 3.1min
# [CV 5/5] END alpha=1.25, colsample_bytree=0.7, gamma=1.0, lambda=7.75, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=2500, subsample=0.6;, score=-7528.249 total time= 3.1min
# 모델 저장됨: xgb_n9000_lr0.02_md9_mcw8_sub0.7_csbt0.8_g0.0_lambda3.25_alpha2.5_train_rmse3069.6516_val_rmse5447.2396.model, Train RMSE: 3069.6516, Validation RMSE: 5447.2396

# %%
from sklearn import metrics

# 예측 수행
pred_2 = best_xgb_model.predict(X_val)

# RMSE 계산
rmse_result = np.sqrt(metrics.mean_squared_error(y_val, pred_2))

# 결과 출력 및 파일 저장
print(f'RMSE test: {rmse_result}')

# 결과를 파일에 저장
with open("rmse_result.txt", "w") as f:
    f.write(f'RMSE test: {rmse_result}\n')
    f.write(f"최적 파라미터: {best_params}, Best RMSE: {best_rmse:.4f}")
# Out:
# RMSE test: 5447.239595048805

# %%
# 학습된 모델을 저장합니다. Pickle 라이브러리를 이용하겠습니다.
with open('saved_modelrandom.pkl', 'wb') as f:
    pickle.dump(best_xgb_model, f)

# %%
# 저장된 모델을 불러옵니다.
with open('saved_modelrandom.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
X_test = dt_test.drop(['target'], axis=1)

real_test_pred = model.predict(X_test)

# %%
# 앞서 예측한 예측값들을 저장합니다.
preds_df = pd.DataFrame(real_test_pred.astype(int), columns=["target"])
preds_df.to_csv('output_random.csv', index=False)
